# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib widget
fig, ax = plt.subplots()
ax.plot([0, 1, 2], [0, 1, 4])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Maximos, minimos y amplitud

# %%
mt = np.random.randint(0, 100, (5, 5))
#Muestra el maximo dentro de la matriz o dimension especificada
mt.max()
#Muestra el minimo dentro de la matriz o dimension especificada
mt.min()
#Muestra el promedio dentro de la matriz o dimension especificada
mt.mean()
# Out:
# Running cells with '.venv (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/luca/Proyectos/Fundamentals/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
